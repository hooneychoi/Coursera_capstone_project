# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# Manhattan is probably the most famous city in the world. A fact says 14.6 million tourists visited the lower Manhattan in 2018. Because of that, Manhattan owns thousands of restaurants to feed all these tourists from all over the world.
#
# As a tourist, how do we choose the right neighborhood for my taste of restaurants? This is the problem that this report can resolve.

# %% [markdown]
# # Data

# %% [markdown]
# <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json">Lat and lon coordinates of manhattan</a>
# <br>
# <a href="https://en.wikipedia.org/wiki/List_of_Manhattan_neighborhoods">List of Manhattan neighborhoods</a>
# <br>
# and we will be using Foursquare data as well.

# %% [markdown]
# # Methodology

# %% [markdown]
# <p>Get coordinates of each neighborhood in Manhattan</p>
# <p>Display all neighborhood on the map</p>

# %% [markdown]
# ![2021-04-21_02-51-47.png](attachment:f7d1c871-c0ca-47d0-879a-ca7bf5996ed4.png)

# %% [markdown]
# <p>Display Top 10 most occuring venues per cuisine</p>

# %% [markdown]
# ![2021-04-21_02-54-45.png](attachment:7016bcf2-0b35-441b-8191-e17c8199ce37.png)

# %% [markdown]
# <p>Cluster each restaurant</p>

# %% [markdown]
# ![2021-04-21_02-58-13.png](attachment:5108eeff-cbeb-48eb-9d2e-bffd219647d7.png)

# %% [markdown]
# # Results

# %% [markdown]
# <p>Most common restaurant for each neighborhood</p>

# %% [markdown]
# ![2021-04-21_02-59-54.png](attachment:d88b06f4-f150-4f35-b7a1-e4943d8ccd8e.png)

# %% [markdown]
# <p>Display it on the map</p>

# %% [markdown]
# ![2021-04-21_03-01-12.png](attachment:336334ca-6800-42f8-9801-39e5730e763f.png)

# %% [markdown]
# # Discussion

# %% [markdown]
# <p>Manually searching through the app or webiste can be avoided if one could utilize this information and the tools to create such report.</p>
# <p>Especialy when most of the tools are opensource thesedays.</p>

# %% [markdown]
# # Conclusion

# %% [markdown]
# <p>Tourists can look at the report and kinda have an idea what the location is toward into when it comes to find restaurants</p>
# <p>Clustering seems very persuasive and accurate</p>
